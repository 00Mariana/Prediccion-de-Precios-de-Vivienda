# %% [markdown]
# # SMART 4 - Model Comparison
#
# **Goal:** Compare all trained models and select the best one.
#
# **Metrics:** R2 Score, RMSE, NRMSE
#
# **Output:** Best model saved to `models/best_model.joblib`
