# %% [markdown]
# # SMART 3 - Model Training
#
# **Goal:** Train decision tree regression models and achieve R2 > 0.80.
#
# **Input:** `data/processed/train_clean.csv`
#
# **Models to train:**
# - Decision Tree Regressor
# - Random Forest Regressor
# - Ridge Regression
# - Lasso Regression
# - Gradient Boosting Regressor
