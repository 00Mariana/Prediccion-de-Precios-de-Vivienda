# %% [markdown]
# # SMART 4 - Comparacion de Modelos
# **Objetivo:** Comparar los modelos entrenados y seleccionar el mejor antes de crear la app
#
# **Responsable:** [Nombre del companero]
#
# **Fecha:** Inicios de la primera semana de agosto
#
# ---
#
# ## Instrucciones
#
# 1. Cargar los modelos entrenados desde `models/`
# 2. Comparar metricas (R^2, RMSE, MAE) de cada modelo
# 3. Visualizar comparaciones con graficas
# 4. Seleccionar el mejor modelo
# 5. Exportar el modelo final para la API

# %%
# TODO: Tu codigo aqui
# Comparar modelos y generar graficas de evaluacion
